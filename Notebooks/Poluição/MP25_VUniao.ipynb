# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !pip install -q py-climate-health-toolbox
import pandas as pd
import numpy as np
import climahe.climatex as tex

# %% [markdown]
# **Leitura dos dados**

# %%
df2015 = pd.read_excel('/content/drive/Shared drives/Clima&Saúde/Pesquisadores/Gitti_JoãoVictor/Dados - Poluição/Dados tratados/VUniao_MP25/VUniao_MP25_2015.xlsx')
df2016 = pd.read_excel('/content/drive/Shared drives/Clima&Saúde/Pesquisadores/Gitti_JoãoVictor/Dados - Poluição/Dados tratados/VUniao_MP25/VUniao_MP25_2016.xlsx')
df2017 = pd.read_excel('/content/drive/Shared drives/Clima&Saúde/Pesquisadores/Gitti_JoãoVictor/Dados - Poluição/Dados tratados/VUniao_MP25/VUniao_MP25_2017.xlsx')
df2018 = pd.read_excel('/content/drive/Shared drives/Clima&Saúde/Pesquisadores/Gitti_JoãoVictor/Dados - Poluição/Dados tratados/VUniao_MP25/VUniao_MP25_2018.xlsx')
df2019 = pd.read_excel('/content/drive/Shared drives/Clima&Saúde/Pesquisadores/Gitti_JoãoVictor/Dados - Poluição/Dados tratados/VUniao_MP25/VUniao_MP25_2019.xlsx')
df2020 = pd.read_excel('/content/drive/Shared drives/Clima&Saúde/Pesquisadores/Gitti_JoãoVictor/Dados - Poluição/Dados tratados/VUniao_MP25/VUniao_MP25_2020.xlsx')

# %% [markdown]
# **Preparação dos dados**

# %%
df2015['Data'] = pd.to_datetime(df2015['Data'], format='%Y/%m/%d')
df2016['Data'] = pd.to_datetime(df2016['Data'], format='%Y/%m/%d')
df2017['Data'] = pd.to_datetime(df2017['Data'], format='%Y/%m/%d')
df2018['Data'] = pd.to_datetime(df2018['Data'], format='%d/%m/%Y')
df2019['Data'] = pd.to_datetime(df2019['Data'], format='%Y/%m/%d')
df2020['Data'] = pd.to_datetime(df2020['Data'], format='%d/%m/%Y')

df = pd.concat([df2015, df2016, df2017, df2018, df2019, df2020])
df = df.dropna(subset = ['Média Horária'])
df = df.rename(columns={'Data': 'DATE'})

df_con_max = df.groupby('DATE').max()
df_con_min = df.groupby('DATE').min()

df_con_max = df_con_max.rename(columns={'Média Horária': 'CON_MAX'})
df_con_min = df_con_min.rename(columns={'Média Horária': 'CON_MIN'})

merge = pd.merge(df_con_max['CON_MAX'],df_con_min['CON_MIN'],on='DATE',how='left')
merge = merge.reset_index()
merge = tex.complete_df(merge)
merge = tex.date_toDay365(merge)
merge = tex.drop_leapday(merge)
df_final = merge
df_final['YEAR'] = df_final['DATE'].dt.year

# %% [markdown]
# **Dataset gerado para definir a normal de poluição**

# %%
normal_pol = df_final[(df_final['DATE']>='2015-01-01')&(df_final['DATE']<='2020-12-31')]
normal_pol=normal_pol.reset_index()
del normal_pol['index']
normal_pol['pct_column'] = np.nan

# %% [markdown]
# **Database gerado para análise**

# %%
database = df_final[(df_final['DATE']>='2015-01-01')&(df_final['DATE']<='2020-12-31')]

# %% [markdown]
# **Criação do DataFrame para definir o mínimo e máximo de poluição das ondas**

# %%
df_pct = pd.DataFrame() 
df_pct['DAY365']=range(1,366) 
df_pct=df_pct.set_index(['DAY365'])

# %% [markdown]
# **Inicialmente, utilizou-se o percentil 90 de dia para dia**

# %% [markdown]
# df_pct['MAX90pct'] = df_pct.index.map(lambda day365_index:
#                                       tex.get_percentile(normal_pol,day365_index,'CON_MAX',0.9,15))
# df_pct['MIN90pct'] = df_pct.index.map(lambda day365_index:
#                                       tex.get_percentile(normal_pol,day365_index,'CON_MIN',0.9,15))

# %% [markdown]
# **Em seguida, considerou-se o percentil 90 para todo o Dataset**

# %% [markdown]
# df_pct['MAX90pct'] = normal_pol['CON_MAX'].quantile(0.9)
# df_pct['MIN90pct'] = normal_pol['CON_MIN'].quantile(0.9)

# %% [markdown]
# **Finalmente, o DataFrame foi contruído com base no nível crítico de poluição**

# %%
df_pct['MAX90pct'] = 50
df_pct['MIN90pct'] = 0

# %%
df_aux=pd.DataFrame()
database.set_index(['DAY365'],inplace=True) 

for year in database.DATE.dt.year.unique(): 
    df_year = database[database.DATE.dt.year == year]
    df_year.loc[:,'above_pct'] = 0
    mask_pw = (df_year['CON_MAX'] >= df_pct['MAX90pct']) & (df_year['CON_MIN'] >= df_pct['MIN90pct'])
    df_year.loc[mask_pw,'above_pct'] = 1 
    if df_aux is None: 
        df_aux = df_year
    else:
        df_aux=df_aux.append(df_year) 
    
df_aux=df_aux.reset_index()
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:1596: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:1763: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:1763: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:1596: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:1763: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:1763: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:1596: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:1763: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:1763: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:1596: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:1763: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:1763: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:1596: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:1763: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:1763: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:1596: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:1763: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:1763: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)

# %%
df_wave = df_aux

# %%
check_pattern = df_wave.rolling(3)['above_pct'].apply(lambda x: all(np.equal(x, [1,1,1])),raw=True) 
check_pattern = check_pattern.fillna(False).astype(bool)
pattern_idx = np.where(check_pattern)[0] 
    
subset = [range(idx-3+1, idx+1) for idx in pattern_idx] 
     
idx_list = [item for sublist in subset for item in sublist] 
    
idx_list=list(set(idx_list))  
    
df_wave['PW']=0 
df_wave['PW'].iloc[idx_list]=1
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %% [markdown]
# **Dias de onda de poluição**

# %%
df_wave[df_wave['PW']==1]
# Out:
#       DAY365       DATE  CON_MAX  CON_MIN  YEAR  above_pct  PW
# 194      195 2015-07-14     68.0      1.0  2015          1   1
# 195      196 2015-07-15     52.0      5.0  2015          1   1
# 196      197 2015-07-16     64.0      7.0  2015          1   1
# 197      198 2015-07-17     60.0      4.0  2015          1   1
# 198      199 2015-07-18     51.0      4.0  2015          1   1
# ...      ...        ...      ...      ...   ...        ...  ..
# 1766     307 2019-11-03     56.0      9.0  2019          1   1
# 1767     308 2019-11-04     50.0      3.0  2019          1   1
# 1943     119 2020-04-29     55.0      4.0  2020          1   1
# 1944     120 2020-04-30     55.0     10.0  2020          1   1
# 1945     121 2020-05-01     59.0     11.0  2020          1   1
#
# [278 rows x 7 columns]

# %%
df_wave.to_csv('Critical Pollution MP25_VUniao')

# %% [markdown]
# **Níveis de poluição:**

# %% [markdown]
# **Boa: 0 ~ 25 (µg/m3)**

# %% [markdown]
# **Moderada: 25 ~ 50 (µg/m3)**

# %% [markdown]
# **Ruim: 50 ~ 75 (µg/m3)**

# %% [markdown]
# **Muito ruim: 75 ~ 125 (µg/m3)**

# %% [markdown]
# **Péssima: > 125 (µg/m3)**
